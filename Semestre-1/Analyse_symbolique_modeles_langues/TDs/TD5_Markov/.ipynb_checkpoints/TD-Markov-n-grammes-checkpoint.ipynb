# %% [markdown]
# # Exercice 0 : préparer les données

# %% [markdown]
# Récupérez sur le site du [projet Gutenberg](https://gutenberg.org/) les trois parties du roman `À l'ombre des jeunes filles en fleurs` que vous mettrez dans un dossier appelé `proust`. Il faut les télécharger en **plain text UTF-8**.
#
# Nettoyez ces fichiers afin de n'avoir plus que le texte du roman (il faut retirer du contenu au début et à la fin de chaque fichier).
#
# Complétez et exécutez ensuite les cellules suivantes.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\andre\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\andre\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\andre\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\andre\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\andre\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\andre\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import collections
import math
import random
import nltk
from nltk.tokenize import sent_tokenize


tokenizer = nltk.RegexpTokenizer(r"([A-Z][A-Z0-9.]+|[0-9]+[,.][0-9]+|[cdjlmnst]'|qu'|[\w'-]+|\S)")

NB_MOTS_MAXI = 100 # le nombre maximum de mot qu'on va générer à la suite
ponctuation = ".?!" # les ponctuations fortes, ça sera utile

# %%
def lire(path):
    with open(path, encoding= 'utf-8') as input_stream:
        return [tokenizer.tokenize(sentence) for sentence in sent_tokenize(input_stream.read())]

# %%
corpus = []
corpus.extend(lire("C:/Users/andre/OneDrive/Bureau/proust/2998-0.txt"))
corpus.extend(lire("C:/Users/andre/OneDrive/Bureau/proust/2999-0.txt"))
corpus.extend(lire("C:/Users/andre/OneDrive/Bureau/proust/3000-0.txt"))

# %% [markdown]
# # Exercice 1 : chaîne de Markov de premier ordre (unigrammes)

# %% [markdown]
# ## a. Compter les transitions
#
# Écrivez une fonction `compter_transitions_unigrammes` qui, étant donné un corpus (séquences de phrases, une phrase étant une séquence de mot), va compter les différentes transitions d'un mot à l'autre dans le corpus.
#
# Le résultat prendra la forme d'un dictionnaire à deux niveaux :
# - Le premier niveau sera le mot précédent
# - le second niveau sera le comptage du mot courant étant donné le mot précédent.

# %%
def compter_transitions_unigrammes(corpus):
    transitions = {}

    for phrase in corpus:
        prev = ""
        for token in phrase:
            if prev not in transitions:
                transitions[prev] = {}
            if token not in transitions[prev]:
                transitions[prev][token] = 0
            transitions[prev][token] += 1
            prev = token

    return transitions

# %% [markdown]
# ## b. Transformer des comptes en probabilité
#
# Écrivez une fonction `probabilifier` qui, étant donné des comptes de transitions, transforme ces comptes en probabilité.
#
# La somme des probabilités des transitions partant d'un même mot doit sommer à 1 (ou presque 1, les nombres étant petits, des imprécisions peuvent arriver).
#
# Par exemple, la somme des transitions partant du mot `Si` doit sommer à 1.

# %%
def probabilifier(comptes_transitions):
    for token in comptes_transitions:
        total = sum(comptes_transitions[token].values())
        for nxt in comptes_transitions[token]:
            comptes_transitions[token][nxt] /= total

    return comptes_transitions

# %% [markdown]
# ## c. Créer une chaîne de Markov d'ordre 1
#
# En utilisant les fonctions précédentes, écrivez une fonction `chaine_markov_unigramme` qui, étant donné un corpus, renvoie une chaîne de Markov d'ordre 1 (probabilités de transitions d'un mot à un autre).

# %%
def chaine_markov_unigramme(corpus):
    transitions = compter_transitions_unigrammes(corpus)

    return probabilifier(transitions)

# %%
markov_chain = chaine_markov_unigramme(corpus)

# %% [markdown]
# ## d. Générer des phrases avec votre chaîne de Markov
#
# Écrivez une fonction `generer_unigramme` qui, étant donné un token de départ, va générer une phrase.
#
# On considère que nous sommes à la fin d'une phrase dès que l'on atteint une ponctuation forte ('.', '?', '!').
#
# Pour générer le prochain mot, on prendra systématiquement le mot le plus probable étant donné le mot précédent.
#
# Afin de vérifier le bon fonctionnement de la fonction, vous générerez d'abord une phrase commençant par `Si`.

# %%
def generer_unigramme(markov_chain, start_token):
    maximum = NB_MOTS_MAXI
    token = start_token
    print(token, end=" ")
    prev = token
    while token not in ponctuation and maximum > 0:
        nxt = sorted([x for x in markov_chain[prev].items()], key=lambda x: -x[1])
        token = nxt[0][0]
        prev = token
        maximum -= 1
        print(token, end=" ")

# %%
generer_unigramme(markov_chain, "Si")
# Out:
# Si vous avez pas , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et de la vie , et

# %% [markdown]
# ## e. Améliorer la génération
#
# Comme vous avez pu le constater, la génération est assez... décevante. Pour améliorer la génération automatique, nous allons ajouter un peu d'aléatoire.
#
# Modifiez la fonction `generer_unigramme` pour y ajouter un argument `n_best` qui dira de prendre non pas le mot le plus probable, mais un mot au hasard parmi les `n_best` plus probables.

# %%
def generer_unigramme(markov_chain, start_token, n_best=1):
    maximum = NB_MOTS_MAXI
    token = start_token
    print(token, end=" ")
    prev = token
    while token not in ponctuation and maximum > 0:
        nxt = sorted([x for x in markov_chain[prev].items()], key=lambda x: -x[1])
        token = random.choice(nxt[:n_best])[0]
        prev = token
        maximum -= 1
        print(token, end=" ")

# %%
generer_unigramme(markov_chain, "Si", 2)
# Out:
# Si , mais qui ne pas , mais je n' est pas de la mer , et de la vie .

# %%
generer_unigramme(markov_chain, "Si", 10)
# Out:
# Si Swann et à un grand jour où nous ne le nom d' être un air glacial , il a une personne que nous .

# %% [markdown]
# # Exercice 2 : chaîne de Markov d'ordre 2 (bigrammes)

# %% [markdown]
# Nous avons fini par avoir une génération acceptable, mais elle demeure encore un peu incohérente. Afin d'améliorer la cohérence de la génération des mots, nous allons utiliser un contexte plus grand afin de générer les mots.
#
# Reprennez les fonctions précédentes (à part `probabilifier` qui restera la même) afin d'utiliser non pas un mot, mais deux mots en contexte.
#
# Si deux mots sont utilisés comme contexte, ils doivent être séparés par une espace.

# %%
def compter_transitions_bigrammes(corpus):
    transitions = {}

    for phrase in corpus:
        prevs = ["", ""]
        for token in phrase:
            prev = " ".join(prevs)
            if prev not in transitions:
                transitions[prev] = {}
            if token not in transitions[prev]:
                transitions[prev][token] = 0
            transitions[prev][token] += 1
            prevs[0] = prevs[1]
            prevs[1] = token

    return transitions

# %%
def chaine_markov_bigramme(corpus):
    transitions = compter_transitions_bigrammes(corpus)

    return probabilifier(transitions)

# %%
markov_chain = chaine_markov_bigramme(corpus)

# %%
def generate_bi(markov_chain, start_token):
    maximum = NB_MOTS_MAXI
    token = start_token
    print(token, end=" ")
    prevs = ["", ""]
    prevs[1] = token
    while token not in ponctuation and maximum > 0:
        prev = " ".join(prevs)
        nxt = sorted([x for x in markov_chain[prev].items()], key=lambda x: -x[1])
        token = nxt[0][0]
        prevs[0] = prevs[1]
        prevs[1] = token
        maximum -= 1
        print(token, end=" ")

# %%
generate_bi(markov_chain, "Si")
# Out:
# Si j' avais été sur la plage , nous ne sommes pas accoutumés , le jour où je ne pouvais pas venir , au contraire , l' idée de moi , mais qui ne sont pas les mêmes que font travailler pour elles , et qui , à la fois , et qui , à la fois , et qui , à la fois , et qui , à la fois , et qui , à la fois , et qui , à la fois , et qui , à la fois , et qui , à la fois , et

# %%
def generate_bi(markov_chain, start_token, n_best=1):
    maximum = NB_MOTS_MAXI
    token = start_token
    print(token, end=" ")
    prevs = ["", ""]
    prevs[1] = token
    while token not in ponctuation and maximum > 0:
        prev = " ".join(prevs)
        nxt = sorted([x for x in markov_chain[prev].items()], key=lambda x: -x[1])
        token = random.choice(nxt[:n_best])[0]
        prevs[0] = prevs[1]
        prevs[1] = token
        maximum -= 1
        print(token, end=" ")

# %%
generate_bi(markov_chain, "Si", 2)
# Out:
# Si , au lieu d' être l' actrice le superposait à une autre qui passerait , aux traits réguliers , des gens qui ne se soucie plus du côté de la vie de son père et sans doute en ce qui est le seul qui puisse laisser de l' hôtel de Balbec .

# %%
generate_bi(markov_chain, "Si", 10)
# Out:
# Si tu ne peux imaginer , cette petite espérait pour le grand désir d' être une divination charmante , jolie , et où je n' en est-il de même des recettes de notre séjour des amitiés que le père » , comme il a été en somme si elles n' ont en commun avec des palpitations de cœur à vivre le combat où nous déjeunions , c' était un vulgaire esbrouffeur que le médecin finit par n' être jamais vu mais dont une face déjà taillée et polie à deux collégiens--deux collègues à qui le décidèrent à parler du bout des

# %% [markdown]
# # Exercice 3 : chaîne de Markov d'ordre arbitraire

# %% [markdown]
# Nous y sommes presque ! Nous commençons à avoir une génération de qualité acceptable.
#
# Afin de rendre votre programme plus générique et plus puissant, réécrivez les fonctions précédente afin qu'elles puissent créer des chaînes de Markov de n'importe quel ordre.
#
# L'ordre de la chaîne de Markov devra être rajouté aux fonctions.

# %%
def compter_transitions(corpus, ordre):
    transitions = {}

    for phrase in corpus:
        prevs = ["" for _ in range(ordre)]
        for token in phrase:
            prev = " ".join(prevs)
            if prev not in transitions:
                transitions[prev] = {}
            if token not in transitions[prev]:
                transitions[prev][token] = 0
            transitions[prev][token] += 1
            prevs = prevs[1:]
            prevs.append(token)

    return transitions

# %%
def chaine_markov(corpus, ordre):
    transitions = compter_transitions(corpus, ordre)

    return probabilifier(transitions)

# %%
markov_chain = chaine_markov(corpus, 3)

# %%
def generer(markov_chain, ordre, start_token):
    maximum = NB_MOTS_MAXI
    token = start_token
    print(token, end=" ")
    prevs = ["" for _ in range(ordre)]
    prevs[-1] = token
    while token not in ponctuation and maximum > 0:
        prev = " ".join(prevs)
        nxt = sorted([x for x in markov_chain[prev].items()], key=lambda x: -x[1])
        token = nxt[0][0]
        prevs = prevs[1:]
        prevs.append(token)
        maximum -= 1
        print(token, end=" ")

# %%
generer(markov_chain, 3, "Si")
# Out:
# Si j' avais pu , heure par heure , la passer avec elle , qu' elle-même avec Swann , et n' était pas la peine que j' allasse perdre mon temps à risquer de prendre du mal pour ce qu' il y a une chose curieuse , c' est que je n' avais pas de relations en dehors des autres .

# %%
def generer(markov_chain, ordre, start_token, n_best=1):
    maximum = NB_MOTS_MAXI
    token = start_token
    print(token, end=" ")
    prevs = ["" for _ in range(ordre)]
    prevs[-1] = token
    while token not in ponctuation and maximum > 0:
        prev = " ".join(prevs)
        nxt = sorted([x for x in markov_chain[prev].items()], key=lambda x: -x[1])
        token = random.choice(nxt[:n_best])[0]
        prevs = prevs[1:]
        prevs.append(token)
        maximum -= 1
        print(token, end=" ")

# %%
generer(markov_chain, 3, "Si", 2)
# Out:
# Si , pourtant , malgré tant de correspondances que je perçus dans la suite dirigés mes actes .

# %%
generer(markov_chain, 3, "Si", 10)
# Out:
# Si on disait que la peinture d' Elstir .

# %% [markdown]
# # Exercice 4 : générer plus qu'une seule phrase (bonus)

# %% [markdown]
# Dans les exercices précédents, on générait une seule phrase. Afin de compléter votre générateur, il faut à présent lui ajouter la possibilité de générer plusieurs phrases d'affilée !

# %% [markdown]
# ## a. Se souvenir des mots de la phrase précédente

# %% [markdown]
# Une limitation à la génération que nous avons faite jusqu'ici est que les phrases sont vues indépendamment les unes des autres. Cela empêche la génération d'un texte plus complet qui serait constitué de plusieurs phrases.

# %%
generer(markov_chain, 3, "France", 10)
# Out:
# Ma vie dans l' hôtel avant de la faire apparaître , embaumée dans sa robe d' or .

# %%
generer(markov_chain, 3, "Si", 10)
# Out:
# Si un peu de feinte , si les différences entre les œuvres ne seraient pas reçus dans un salon de lecture pour la description duquel il m' aurait fallu choisir dans le Dante , tour à tour une petite statuette de galant jardinier , des boules de verre où l' on peut tirer véridiquement quelque chose de plus à Tolède car il est admirateur d' un élève de Titien dont je ne saurais m' accommoder , et qui eût ainsi abrégé vos souffrances actuelles , pour les artistes dramatiques , que la joie neutralise , rend virtuelle , ajourne , mais

# %% [markdown]
# ## b. Se souvenir aussi des phrases avec et sans leur contexte

# %% [markdown]
# Comme vous avez pu le constater, si vous entrez un mot qui n'est pas le premier mot du corpus, votre programme échouera. Cela est dû au fait que vous ne gardez plus les phrases sans leur contexte, elle ne peut plus apparaître sans avoir quelques mots qui la précède.
#
# Afin de corriger ce problème, doublez votre corpus :
# - le corpus sans contexte (exercices 1 à 3)
# - le corpus avec contexte (question a)
#
# Et refaites des statistiques, houra, ça marche !

# %% [markdown]
# ## c. Générer plusieurs phrases d'affilée

# %% [markdown]
# La dernière étape est de modifier la fonction `generer` afin de générer, non pas une, mais plusieurs phrases à la suite.
